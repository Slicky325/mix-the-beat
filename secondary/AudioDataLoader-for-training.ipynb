# %%
import deeplake
ds = deeplake.load("hub://activeloop/esc50")
# Out:
# |
# Opening dataset in read-only mode as you don't have write permissions.
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/esc50
# -
# hub://activeloop/esc50 loaded successfully.

# %%
dataloader = ds.pytorch(num_workers=0, batch_size=4, shuffle=False)

# %%
for i in ds:
    print(i)
# Out:
# Dataset(path='hub://activeloop/esc50', read_only=True, index=Index([0]), tensors=['audio', 'labels', 'target', 'fold', 'esc10', 'src_file', 'take'])
# Dataset(path='hub://activeloop/esc50', read_only=True, index=Index([1]), tensors=['audio', 'labels', 'target', 'fold', 'esc10', 'src_file', 'take'])
# Dataset(path='hub://activeloop/esc50', read_only=True, index=Index([2]), tensors=['audio', 'labels', 'target', 'fold', 'esc10', 'src_file', 'take'])
# Dataset(path='hub://activeloop/esc50', read_only=True, index=Index([3]), tensors=['audio', 'labels', 'target', 'fold', 'esc10', 'src_file', 'take'])
# Dataset(path='hub://activeloop/esc50', read_only=True, index=Index([4]), tensors=['audio', 'labels', 'target', 'fold', 'esc10', 'src_file', 'take'])
# Dataset(path='hub://activeloop/esc50', read_only=True, index=Index([5]), tensors=['audio', 'labels', 'target', 'fold', 'esc10', 'src_file', 'take'])
# ...
